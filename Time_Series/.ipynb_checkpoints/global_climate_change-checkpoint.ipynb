# %% [markdown]
# # Overview
#
# ## DESCRIPTION
# ### Global Climate Change Data from 1750－2015
#
# ## SUMMARY
# Some say climate change is the biggest threat of our age while others say it’s a myth based on dodgy science. We are turning some of the data over to you so you can form your own view.
#
# [In this dataset](https://data.world/data-society/global-climate-change-data), we have include several files:
#
# ＊ Global Land and Ocean-and-Land Temperatures (GlobalTemperatures.csv):
#   - Date: starts in 1750 for average land temperature and 1850 for max and min land temperatures and global ocean and land temperatures
#   - LandAverageTemperature: global average land temperature in celsius
#   - LandAverageTemperatureUncertainty: the 95% confidence interval around the average
#   - LandMaxTemperature: global average maximum land temperature in celsius
#   - LandMaxTemperatureUncertainty: the 95% confidence interval around the maximum land temperature
#   - LandMinTemperature: global average minimum land temperature in celsius
#   - LandMinTemperatureUncertainty: the 95% confidence interval around the minimum land temperature
#   - LandAndOceanAverageTemperature: global average land and ocean temperature in celsius
#   - LandAndOceanAverageTemperatureUncertainty: the 95% confidence interval around the global average land and ocean temperature
#
# ＊ Other files include:
#   - Global Average Land Temperature by Country (GlobalLandTemperaturesByCountry.csv)
#   - Global Average Land Temperature by State (GlobalLandTemperaturesByState.csv)
#   - Global Land Temperatures By Major City (GlobalLandTemperaturesByMajorCity.csv)
#   - Global Land Temperatures By City (GlobalLandTemperaturesByCity.csv)
#
# Source: [Kaggle](https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data)
#
# Raw data: [Berkeley Earth data page](http://berkeleyearth.org/data/)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10, 6)

# from matplotlib import style
# style.use('dark_background')

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
path_by_country = r"data-society-global-climate-change\Data_GlobalLandTemperatures_2023\GlobalLandTemperaturesByCountry.csv"
path_by_city = r"data-society-global-climate-change\Data_GlobalLandTemperatures_2023\GlobalLandTemperaturesByMajorCity.csv"
path_by_state = r"data-society-global-climate-change\Data_GlobalLandTemperatures_2023\GlobalLandTemperaturesByState.csv"
path_global_tmpr = r"data-society-global-climate-change\Data_GlobalLandTemperatures_2023\GlobalTemperatures.csv"

df0_cntry = pd.read_csv(path_by_country)
df0_city = pd.read_csv(path_by_city)
df0_state = pd.read_csv(path_by_state)
df0_tmpr = pd.read_csv(path_global_tmpr)

# %%
def reduce_mem_usage(df):
    """ Iterate through all the columns of a dataframe and modify the data type
    to reduce memory usage.
    """
    start_mem = df.memory_usage(deep=True).sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype
        if col_type == 'object' or col_type.name == 'category':
            df[col] = df[col].astype('category')
            # continue
        elif np.issubdtype(col_type, np.integer):
            c_min = df[col].min()
            c_max = df[col].max()
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                df[col] = df[col].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                df[col] = df[col].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                df[col] = df[col].astype(np.int32)
            else:
                df[col] = df[col].astype(np.int64)
        elif np.issubdtype(col_type, np.floating):
            df[col] = pd.to_numeric(df[col], downcast='float')
    
    # # Explicitly handle datetime columns with timezone
    # datetime_cols_with_tz = [col for col in df.columns if df[col].dtype == 'datetime64[ns, tz]']
    # for col in datetime_cols_with_tz:
    #     df[col] = df[col].dt.tz_localize(None)  # Remove timezone information
    
    end_mem = df.memory_usage(deep=True).sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}% \n'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
df0_cntry = reduce_mem_usage(df0_cntry)
df0_city = reduce_mem_usage(df0_city)
df0_state = reduce_mem_usage(df0_state)
df0_tmpr = reduce_mem_usage(df0_tmpr)
# Out:
# Memory usage of dataframe is 82.60 MB
# Memory usage after optimization is: 6.97 MB
# Decreased by 91.6%
#
# Memory usage of dataframe is 77.14 MB
# Memory usage after optimization is: 3.55 MB
# Decreased by 95.4%
#
# Memory usage of dataframe is 131.48 MB
# Memory usage after optimization is: 8.36 MB
# Decreased by 93.6%
#
# Memory usage of dataframe is 0.40 MB
# Memory usage after optimization is: 0.43 MB
# Decreased by -8.7%

# %%
df_cntry = df0_cntry.copy()
df_city = df0_city.copy()
df_state = df0_state.copy()
df_tmpr = df0_tmpr.copy()

# %%
df_cntry.head(5)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
df_city.head(5)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
df_state.head(5)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
df_tmpr.head(5)
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
df_cntry.shape, df_city.shape, df_state.shape, df_tmpr.shape
# Out:
# ((577462, 4), (239177, 7), (645675, 5), (3192, 9))

# %%
df_cntry.isna().sum() / df_cntry.shape[0] * 100
# Out:
# dt                              0.000
# AverageTemperature              5.654
# AverageTemperatureUncertainty   5.526
# Country                         0.000
# dtype: float64

# %%
df_city.isna().sum() / df_city.shape[0] * 100
# Out:
# dt                              0.000
# AverageTemperature              4.600
# AverageTemperatureUncertainty   4.600
# City                            0.000
# Country                         0.000
# Latitude                        0.000
# Longitude                       0.000
# dtype: float64

# %%
df_state.isna().sum() / df_state.shape[0] * 100
# Out:
# dt                              0.000
# AverageTemperature              3.972
# AverageTemperatureUncertainty   3.972
# State                           0.000
# Country                         0.000
# dtype: float64

# %%
df_tmpr.isna().sum() / df_tmpr.shape[0] * 100
# Out:
# dt                                           0.000
# LandAverageTemperature                       0.376
# LandAverageTemperatureUncertainty            0.376
# LandMaxTemperature                          37.594
# LandMaxTemperatureUncertainty               37.594
# LandMinTemperature                          37.594
# LandMinTemperatureUncertainty               37.594
# LandAndOceanAverageTemperature              37.594
# LandAndOceanAverageTemperatureUncertainty   37.594
# dtype: float64

# %%
def info(df):
    # number of lines in total
    print(f'\n\033[1mTotal Lines :\033[0m {df.shape[0]}') 
    # \033[1m {your_text} \033[0m : makes your_text bold

    # number of columns in total
    print(f'\n\033[1mTotal Columns :\033[0m {df.shape[1]}')

    # extract the column names
    columnName = df.columns
    print(f'\n\033[1mColumn Names:\033[0m ' + f'{columnName} \n')

    # number of duplicates in total
    duplicates = df.duplicated().sum()
    print(f'\n\033[1mDuplicates:\033[0m ' + f'{duplicates} \n')

    # overview of the data
    print(f'\033[1mOverview of Data:\033[0m\n')
    infos = df.info()

    # total null values after each category
    nullValues = df.isnull().sum()
    print(f'\n\033[1mNull Values\033[0m\n' + f'{nullValues} \n')

    # Descriptive statistics object columns
    describe = df.describe(include="category").T
    print(f'\n\033[1mDescriptive Statistics:\033[0m\n' + f'{describe} \n')

# %%
info(df_cntry)
# Out:
# Total Lines : 577462
#
# Total Columns : 4
#
# Column Names: Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'Country'], dtype='object')
#
#
# Duplicates: 0
#
# Overview of Data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577462 entries, 0 to 577461
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt                             577462 non-null  category
#  1   AverageTemperature             544811 non-null  float32
#  2   AverageTemperatureUncertainty  545550 non-null  float32
#  3   Country                        577462 non-null  category
# dtypes: category(2), float32(2)
# memory usage: 6.8 MB
#
# Null Values
# dt                                   0
# AverageTemperature               32651
# AverageTemperatureUncertainty    31912
# Country                              0
# dtype: int64
#
#
# Descriptive Statistics:
# ...

# %%
info(df_city)
# Out:
# Total Lines : 239177
#
# Total Columns : 7
#
# Column Names: Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')
#
#
# Duplicates: 0
#
# Overview of Data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239177 entries, 0 to 239176
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt                             239177 non-null  category
#  1   AverageTemperature             228175 non-null  float32
#  2   AverageTemperatureUncertainty  228175 non-null  float32
#  3   City                           239177 non-null  category
#  4   Country                        239177 non-null  category
#  5   Latitude                       239177 non-null  category
#  6   Longitude                      239177 non-null  category
# dtypes: category(5), float32(2)
# memory usage: 3.4 MB
#
# ...

# %%
info(df_state)
# Out:
# Total Lines : 645675
#
# Total Columns : 5
#
# Column Names: Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'State',
#        'Country'],
#       dtype='object')
#
#
# Duplicates: 0
#
# Overview of Data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645675 entries, 0 to 645674
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt                             645675 non-null  category
#  1   AverageTemperature             620027 non-null  float32
#  2   AverageTemperatureUncertainty  620027 non-null  float32
#  3   State                          645675 non-null  category
#  4   Country                        645675 non-null  category
# dtypes: category(3), float32(2)
# memory usage: 8.2 MB
#
# Null Values
# dt                                   0
# AverageTemperature               25648
# AverageTemperatureUncertainty    25648
# ...

# %%
info(df_tmpr)
# Out:
# Total Lines : 3192
#
# Total Columns : 9
#
# Column Names: Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty'],
#       dtype='object')
#
#
# Duplicates: 0
#
# Overview of Data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt                                         3192 non-null   category
#  1   LandAverageTemperature                     3180 non-null   float32
#  2   LandAverageTemperatureUncertainty          3180 non-null   float32
#  3   LandMaxTemperature                         1992 non-null   float32
# ...

# %%
df_cntry['dt'] = pd.to_datetime(df_cntry['dt'])
df_city['dt'] = pd.to_datetime(df_city['dt'])
df_state['dt'] = pd.to_datetime(df_state['dt'])
df_tmpr['dt'] = pd.to_datetime(df_tmpr['dt'])

# %%
df_cntry.columns = ['Date', 'AvgTemp', 'AvgTempUnc', 'Country']
df_city.columns = ['Date', 'AvgTemp', 'AvgTempUnc', 'City', 'Country', 'Lat', 'Long']
df_state.columns = ['Date', 'AvgTemp', 'AvgTempUnc', 'State', 'Country']
df_tmpr.columns = ['Date', 'LandAvgTemp', 'LandAvgTempUnc', 'LandMaxTemp', 'LandMaxTempUnc', 'LandMinTemp', 
                           'LandMinTempUnc', 'LandOceanAvgTemp', 'LandOceanAvgTempUnc']

# %%
df_cntry
# Out:
#              Date  AvgTemp  AvgTempUnc   Country
# 0      1743-11-01    4.384       2.294     Åland
# 1      1743-12-01      NaN         NaN     Åland
# 2      1744-01-01      NaN         NaN     Åland
# 3      1744-02-01      NaN         NaN     Åland
# 4      1744-03-01      NaN         NaN     Åland
# ...           ...      ...         ...       ...
# 577457 2013-05-01   19.059       1.022  Zimbabwe
# 577458 2013-06-01   17.613       0.473  Zimbabwe
# 577459 2013-07-01   17.000       0.453  Zimbabwe
# 577460 2013-08-01   19.759       0.717  Zimbabwe
# 577461 2013-09-01      NaN         NaN  Zimbabwe
#
# [577462 rows x 4 columns]

# %%
df_cntry[df_cntry["Country"] == "Turkey"]
# Out:
#              Date  AvgTemp  AvgTempUnc Country
# 533683 1777-02-01    3.000       3.314  Turkey
# 533684 1777-03-01      NaN         NaN  Turkey
# 533685 1777-04-01    7.678       2.553  Turkey
# 533686 1777-05-01   15.293       3.189  Turkey
# 533687 1777-06-01   18.661       2.993  Turkey
# ...           ...      ...         ...     ...
# 536518 2013-05-01   17.522       0.360  Turkey
# 536519 2013-06-01   20.862       0.240  Turkey
# 536520 2013-07-01   23.335       0.281  Turkey
# 536521 2013-08-01   23.839       0.306  Turkey
# 536522 2013-09-01      NaN         NaN  Turkey
#
# [2840 rows x 4 columns]

# %%
df_city[df_city["Country"] == "Turkey"]
# Out:
#             Date  AvgTemp  AvgTempUnc    City Country     Lat    Long
# 11893 1755-01-01   -3.657       4.084  Ankara  Turkey  39.38N  33.29E
# 11894 1755-02-01   -2.453       3.712  Ankara  Turkey  39.38N  33.29E
# 11895 1755-03-01    4.458       3.421  Ankara  Turkey  39.38N  33.29E
# 11896 1755-04-01      NaN         NaN  Ankara  Turkey  39.38N  33.29E
# 11897 1755-05-01      NaN         NaN  Ankara  Turkey  39.38N  33.29E
# ...          ...      ...         ...     ...     ...     ...     ...
# 96618 2013-05-01   21.723       0.407   Izmir  Turkey  37.78N  26.44E
# 96619 2013-06-01   24.416       0.589   Izmir  Turkey  37.78N  26.44E
# 96620 2013-07-01   26.451       0.277   Izmir  Turkey  37.78N  26.44E
# 96621 2013-08-01   27.430       0.220   Izmir  Turkey  37.78N  26.44E
# 96622 2013-09-01      NaN         NaN   Izmir  Turkey  37.78N  26.44E
#
# [9473 rows x 7 columns]

# %%
df_state[df_state["Country"] == "Turkey"]
# Out:
# Empty DataFrame
# Columns: [Date, AvgTemp, AvgTempUnc, State, Country]
# Index: []

# %%
import re

# Function to convert location values to numeric value
def convert_loc(value):
    num_part = re.sub(r'[^\d.]', '', value)
    num_value = float(num_part)
    
    if 'W' in value or 'S' in value:
        num_value *= -1
    
    return num_value

df_city['Lat'] = df_city["Lat"].apply(convert_loc)
df_city['Long'] = df_city["Long"].apply(convert_loc)

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239177 entries, 0 to 239176
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        239177 non-null  datetime64[ns]
#  1   AvgTemp     228175 non-null  float32
#  2   AvgTempUnc  228175 non-null  float32
#  3   City        239177 non-null  category
#  4   Country     239177 non-null  category
#  5   Lat         239177 non-null  category
#  6   Long        239177 non-null  category
# dtypes: category(4), datetime64[ns](1), float32(2)
# memory usage: 4.6 MB

# %%
# df['month'] = df["dt"].apply(lambda i: i.month)

df_cntry['month'] = df_cntry['Date'].dt.month
df_cntry['year'] = df_cntry['Date'].dt.year

df_city['month'] = df_city['Date'].dt.month
df_city['year'] = df_city['Date'].dt.year

df_state['month'] = df_state['Date'].dt.month
df_state['year'] = df_state['Date'].dt.year

df_tmpr['month'] = df_tmpr['Date'].dt.month
df_tmpr['year'] = df_tmpr['Date'].dt.year

# %% [markdown]
# # Visualization

# %%
df_list = [df_cntry, df_city, df_state, df_tmpr]
cmap = plt.cm.get_cmap("gray")
plt.figure(figsize=(35, 7))

for i in range(1, 5):        
    plt.subplot(1, 4, i)
    
    # plt.title(f"{df_list[i-1]} Nulls", y=1.005)
    sns.heatmap(df_list[i-1].isna(), yticklabels=False, cbar=False, cmap=cmap)
    plt.xticks(rotation=75)
    
    plt.xlabel("Columns")
    plt.ylabel("Nulls")
    plt.tight_layout()
    plt.show()
    
    
    
    
    
# plt.figure(figsize=(14, 20))
# days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# for i,j in enumerate(days):
#     plt.subplot(5, 2, i+1)
#     df_day = df_day_based_member_casual[df_day_based_member_casual["day_name"] == j]
#     plt.title(f"{j}s")
#     sns.lineplot(x="date", y="ride_id", hue="member_casual", data=df_day, sort=False)
#     plt.ticklabel_format(style="plain", axis="y")
#     plt.xlabel("Date")
#     plt.ylabel("Ride Counts")        

# plt.suptitle("Member-Casual Based Daily Usage Line Plot", y=1.01)
# plt.tight_layout()

# plt.show()

# %%
plt.figure(figsize=(20, 5))

data = df_cntry[df_cntry["Date"] >= "2000-01-01"]

sns.lineplot(x="Date", y="AvgTemp", data=data);
plt.xlabel("Date")
plt.ylabel("Average Temperature")
plt.ticklabel_format(style="plain", axis="y")

# %%
plt.figure(figsize=(15, 4))

data = df_cntry[df_cntry["Date"] >= "2000-01-01"]
data = data[data['Date'].dt.month == 1]

sns.lineplot(x="Date", y="AvgTemp", data=data);
plt.xlabel("Date")
plt.ylabel("Average Temperature")
plt.ticklabel_format(style="plain", axis="y")

# %%
plt.figure(figsize=(15, 4))

data = df_cntry[df_cntry["Date"] >= "2000-01-01"]
data = data[data['Date'].dt.month == 7]

sns.lineplot(x="Date", y="AvgTemp", data=data);
plt.xlabel("Date")
plt.ylabel("Average Temperature")
plt.ticklabel_format(style="plain", axis="y")

# %%
plt.figure(figsize=(15, 4))

data = df_cntry[df_cntry["Date"] >= "2000-01-01"]
data = data[data['Date'].dt.month < 7]

sns.lineplot(x="Date", y="AvgTemp", data=data, hue="month");
plt.xlabel("Date")
plt.ylabel("Average Temperature")
plt.ticklabel_format(style="plain", axis="y")

# %%
plt.figure(figsize=(15, 4))

data = df_cntry[df_cntry["Date"] >= "2000-01-01"]
data = data[data['Date'].dt.month > 7]

sns.lineplot(x="Date", y="AvgTemp", data=data, hue="month");
plt.xlabel("Date")
plt.ylabel("Average Temperature")
plt.ticklabel_format(style="plain", axis="y")

# %%
plt.figure(figsize=(18, 8))

data = df_cntry[(df_cntry["Country"] == "Turkey") & (df_cntry["Date"] >= "2008-01-01")]
plt.plot(data['Date'], data['AvgTemp'], color="purple", marker='o', label='Average Temperature')
plt.fill_between(data['Date'], data['AvgTemp'] - data['AvgTempUnc'], data['AvgTemp'] + data['AvgTempUnc'],
                 color="cyan", alpha=0.3, label='95% Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('Average Temperature with Confidence Interval')
plt.grid(True)
plt.xticks(data['Date'], data['Date'].dt.strftime('%Y-%m'), rotation=45)
plt.yticks(np.arange(round(min(data['AvgTemp']), 0), max(data['AvgTemp'])+1, 2.0))
plt.legend()
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(18, 8))

data = df_cntry[(df_cntry["Country"] == "Turkey") & (df_cntry["Date"] >= "2008-01-01")]
plt.bar(data['Date'], data['AvgTemp'], yerr=data['AvgTempUnc'], width=15, color="purple", align='center', capsize=3)
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.title('Average Temperature with Confidence Intervals')
plt.grid(True, axis='y')
plt.xticks(data['Date'], data['Date'].dt.strftime('%Y-%m'), rotation=45)
plt.yticks(np.arange(round(min(data['AvgTemp']), 0), max(data['AvgTemp'])+1, 2.0))
plt.tight_layout()

plt.show()
